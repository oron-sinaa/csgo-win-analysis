# %%
#dataset sourced by an individual csgo player from https://www.kaggle.com/thesiff/counterstrike
#simple analysis of win/loss data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import train_test_split function
from sklearn.model_selection import train_test_split 

# Import Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

 #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

from sklearn import tree
from sklearn.tree import export_graphviz

# %%
df = pd.read_csv('CSGOComplete.csv')
df.head(10)
# Out:
#        Map  Day  Month  Year       Date  Wait Time(s)   Match Time(s)  \
# 0   Mirage    3      8  2018   3/8/2018           327            2906
# 1   Mirage    2      8  2018   2/8/2018           336            2592
# 2   Mirage   31      7  2018  31/7/2018           414            2731
# 3   Mirage   31      7  2018  31/7/2018           317            2379
# 4   Mirage   30      7  2018  30/7/2018           340            3467
# 5   Mirage   29      7  2018  29/7/2018           391            1881
# 6  Dust II   28      7  2018  28/7/2018           274            3194
# 7   Mirage   27      7  2018  27/7/2018           291            2859
# 8   Mirage   27      7  2018  27/7/2018           184            2300
# 9   Mirage   27      7  2018  27/7/2018           375            2184
#
#    Team A Rounds  Team B Rounds  Ping  Kills  Assists  Deaths  Mvp's  HS%  \
# 0             16             13   215     17        2      21      2    5
# 1             16             11   199     13        4      24      2    0
# 2             16             14    85     15        3      18      3   26
# 3             11             16    93     12        2      15      2   16
# 4             15             15    94     33        5      20      5   30
# 5             16              4    88     13        2      17      1   38
# 6             16             14    89     19        5      24      2   15
# 7             16             14    82     17        1      25      0   35
# 8             16              8   112     25       10      12      4   16
# 9              6             16    89     13        1      17      0   61
#
#    Points Result
# 0      45    Win
# 1      40   Lost
# 2      37    Win
# 3      30   Lost
# 4      83    Tie
# 5      34   Lost
# 6      52   Lost
# 7      37   Lost
# 8      70    Win
# 9      31   Lost

# %%
col_names = ['Map', ' Match Time(s)', 'Ping', 'Kills', 'Assists', 'Deaths', 'HS%', 'Mvp\'s', 'Points', 'Result']
model_df = df[col_names]

print ("Dataset Length: ", len(model_df)) 
print ("Dataset Shape: ", model_df.shape)     
model_df.head(10)
# Out:
# Dataset Length:  1133
# Dataset Shape:  (1133, 10)
#        Map   Match Time(s)  Ping  Kills  Assists  Deaths  HS%  Mvp's  Points  \
# 0   Mirage            2906   215     17        2      21    5      2      45
# 1   Mirage            2592   199     13        4      24    0      2      40
# 2   Mirage            2731    85     15        3      18   26      3      37
# 3   Mirage            2379    93     12        2      15   16      2      30
# 4   Mirage            3467    94     33        5      20   30      5      83
# 5   Mirage            1881    88     13        2      17   38      1      34
# 6  Dust II            3194    89     19        5      24   15      2      52
# 7   Mirage            2859    82     17        1      25   35      0      37
# 8   Mirage            2300   112     25       10      12   16      4      70
# 9   Mirage            2184    89     13        1      17   61      0      31
#
#   Result
# 0    Win
# 1   Lost
# 2    Win
# 3   Lost
# 4    Tie
# 5   Lost
# 6   Lost
# 7   Lost
# 8    Win
# 9   Lost

# %%
# def calculate_average(weights):
#     average_weights = []
#     for i in range(1,len(weights)-1):
#         average_weights.append(weights[i] + (weights[i+1] - weights[i])/2)
#     return pd.Series(average_weights)

# def calculate_gini_impurity(df, weights, param):
#     min_weighted_average_gini_impurity = 1
#     for element in average_weights_ping:
#         left_wins = df.loc[(df['Ping']<element) & (df['Result']=='Win')].size
#         left_loss = df.loc[(df['Ping']<element) & (df['Result']=='Lost')].size
#         left_tie = df.loc[(df['Ping']<element) & (df['Result']=='Tie')].size
#         left_total = left_wins + left_loss + left_tie
#         left_impurity = 1 - (left_wins/left_total)**2 - (left_loss/left_total)**2
        
#         right_wins = df.loc[(df['Ping']>=element) & (df['Result']=='Win')].size
#         right_loss = df.loc[(df['Ping']>=element) & (df['Result']=='Lost')].size
#         right_tie = df.loc[(df['Ping']>=element) & (df['Result']=='Tie')].size
#         right_total = right_wins + right_loss + right_tie
#         right_impurity = 1 - (right_wins/right_total)**2 - (right_loss/right_total)**2
        
#         weighted_average_gini_impurity = (left_total/(left_total+right_total))*left_impurity + (right_total/(left_total+right_total))*right_impurity

        
#         print(element)
#         if()
#         min_weighted_average_gini_impurity = min(min_weighted_average_gini_impurity, weighted_average_gini_impurity)

#         print("----------------------------------")


#     return weights

# params = [' Match Time(s)', 'Ping', 'Kills', 'Assists', 'Deaths', 'Mvp\'s', 'HS%', 'Points']

# for element in params:     
#     df_param = df[[element,'Result']]
#     df_param = df_param.sort_values([element])
#     average_weights_element = calculate_average(df_ping[element].unique())
#     calculate_gini_impurity(df_ping, average_weights_ping)
#     # average_weights_ping

# %%
# split dataset in features and target variable
feature_cols = [' Match Time(s)', 'Ping', 'Kills', 'Assists', 'Deaths', 'Mvp\'s', 'HS%', 'Points']
X = model_df[feature_cols] # Features
y = model_df['Result'] # Target variable

# %%
 # 70% training and 30% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Create Decision Tree classifer object
clf_gini = DecisionTreeClassifier(criterion = "gini",
                                  random_state = 100,
                                  max_depth=4,
                                  min_samples_split=10,
                                  min_samples_leaf=5)

# Train Decision Tree Classifer
clf_giniclf_gini = clf_gini.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf_gini.predict(X_test)
# print("Predicted values:") 
# print(y_pred)

# %%
# Model Accuracy, how often is the classifier correct?
print("Confusion Matrix : \n", confusion_matrix(y_test, y_pred))
print("Accuracy : ", accuracy_score(y_test, y_pred)*100)
print("Report : \n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix :
#  [[152   0  25]
#  [ 21   1   2]
#  [ 47   0  92]]
# Accuracy :  72.05882352941177
# Report :
#                precision    recall  f1-score   support
#
#         Lost       0.69      0.86      0.77       177
#          Tie       1.00      0.04      0.08        24
#          Win       0.77      0.66      0.71       139
#
#     accuracy                           0.72       340
#    macro avg       0.82      0.52      0.52       340
# weighted avg       0.75      0.72      0.70       340

# %%
newdf = df.drop(columns = ['Map','Day','Month','Year','Date','Wait Time(s)'])
newdf = newdf.drop(columns = ['Team A Rounds','Team B Rounds','Kills','Assists','Deaths','Mvp\'s','HS%','Points'])
newdf = newdf.sort_values(['Ping'])
newdf.head(10)
# Out:
#        Match Time(s)  Ping Result
# 671             1899     0    Win
# 89              2752     0    Tie
# 746             1529     0   Lost
# 341             2291     0    Win
# 1057            2280     0   Lost
# 351             1798     0   Lost
# 291             2973     0    Tie
# 290             2922     0    Tie
# 206             2214     0   Lost
# 285             1619     0   Lost

# %%
winner = newdf.loc[(newdf['Ping'] >= 150) & (newdf['Result'] == 'Win')]
loser = newdf.loc[(newdf['Ping'] >= 150) & (newdf['Result'] == 'Lost')]
print('+ Average match time = {} minutes'.format(int(newdf['Match Time sec'].mean()/60)))
a = newdf.loc[(newdf[' Match Time sec'] >= 2280) & (newdf['Result'] == 'Win')].shape[0]
b = newdf.loc[(newdf[' Match Time sec'] <= 2280) & (newdf['Result'] == 'Win')].shape[0]
print('+ Wins if time greater than 38 minutes = {}'.format(a))
print('+ Wins if time less than 38 minutes = {}'.format(b))
print('+ The ratio {0:.4f} concludes that length of match does not have a big impact on win/loss'.format(a/b))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Match Time sec'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-2cbd14f0b9e5> in <module>
#       1 winner = newdf.loc[(newdf['Ping'] >= 150) & (newdf['Result'] == 'Win')]
#       2 loser = newdf.loc[(newdf['Ping'] >= 150) & (newdf['Result'] == 'Lost')]
# ----> 3 print('+ Average match time = {} minutes'.format(int(newdf['Match Time sec'].mean()/60)))
#       4 a = newdf.loc[(newdf[' Match Time sec'] >= 2280) & (newdf['Result'] == 'Win')].shape[0]
#       5 b = newdf.loc[(newdf[' Match Time sec'] <= 2280) & (newdf['Result'] == 'Win')].shape[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Match Time sec'

# %%
total = loser.shape[0] + winner.shape[0]
winratio = winner.shape[0]/total
print('+ Chances of winning with ping greater than 150ms = {0:.4f}%'.format(winratio*100))
# Out:
# + Chances of winning with ping greater than 150ms = 39.0625%

# %%
win150 = newdf.loc[(newdf['Ping'] <= 150) & (newdf['Result'] == 'Win')]
loss150 = newdf.loc[(newdf['Ping'] <= 150) & (newdf['Result'] == 'Lost')]
total150 = loss150.shape[0] + win150.shape[0]
winratio150 = win150.shape[0]/total150
print('+ Chances of winning with ping less than 150ms = {0:.4f}%'.format(winratio150*100))
# Out:
# + Chances of winning with ping less than 150ms = 47.0051%

# %%
mvpg2 = df.loc[(df['Mvp\'s']>2) & (df['Result'] == 'Win')].shape[0]
mvpl2 = df.loc[(df['Mvp\'s']<2) & (df['Result'] == 'Win')].shape[0]
ratio = mvpg2 / mvpl2
print('+ Winning ratio if you mvp\'s were greater than 2 = {0:.2f}'.format(ratio))
# Out:
# + Winning ratio if you mvp's were greater than 2 = 1.22

# %%
print('+ Conclusion:\n** There\'s a good chance that you will lose 5 matches out of 10 regularly if you got a fair competition.\n** Ping does matter but would make you win just 1 more match if you\'ve the upper side with ping and similar competition.')
# Out:
# + Conclusion:
# ** There's a good chance that you will lose 5 matches out of 10 regularly if you got a fair competition.
# ** Ping does matter but would make you win just 1 more match if you've the upper side with ping and similar competition.

# %%
ntie = newdf.loc[(newdf['Result'] == 'Tie')].shape[0]
ratiotie = ntie / newdf.shape[0]
print('+ Also tie percentage: {0:.4f}%'.format(ratiotie*100))
# Out:
# + Also tie percentage: 7.5022%
